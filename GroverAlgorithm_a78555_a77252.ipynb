# %% [markdown]
# # Trabalho Prático

# %% [markdown]
# ## Grupo 7
# #### Filipe Barbosa a77252
# #### Hugo Ferreira  a78555

# %% [markdown]
# ## Descrição

# %% [markdown]
# Neste trabalho prático é pretentido descobrir um $s$ tal que $s\equiv N\space mod\space 8$,sendo N o número de grupo atribuido, usando um algoritmo quântico. O algoritmo quântico que vai ser usado é o algoritmo $Grover$.
# Os possíveis casos vão ser $000$,$001$,$010$,$011$,$100$,$101$,$110$,$111$.
# Como no nosso $N=7$, depois de converter para binário vamos ter que o resultado pretendido vai ser $111$.

# %% [markdown]
# ## Algoritmo de Grover

# %% [markdown]
# Para a construção do algoritmo de Grover vamos ter as seguintes etapas:
#  - Inicialização
#  - Oráculo
#  - Amplificação

# %% [markdown]
# ### Inicialização

# %% [markdown]
# Vamos inicializar os estados do sistema com a mesma amplitude.
#
# $$ \sum_{x_i} \lvert x_i \rangle$$
#
# Esta inicialização é feita através da sobreposição do $qubits$ que em $qiskit$ é conseguido usando um gate de Hadamard.

# %%
from qiskit import *
# %matplotlib inline
from qiskit.tools.visualization import *
from qiskit import IBMQ
from qiskit.providers.ibmq import least_busy

# %%
n=3

cr = ClassicalRegister(n, 'c')
qr = QuantumRegister(n, 'q')

qc = QuantumCircuit(qr, cr)
qc.h(qr)
qc.draw('mpl')

# %% [markdown]
# ### Oráculo

# %% [markdown]
# Vamos criar o oráculo que vai ser responsável por mudar a fase do qubit para o nosso número em binário pretendido.
# Como no nosso caso o número pretendido é o $111$ não vamos precisar aplicar nenhum gate-X e simplesmente vamos aplicar o um gate-CCZ que pode ser construido em $qiskit$ através da sequência gate-H,gate-CCX,gate-H.

# %%
def oracle(circuit,q):
    circuit.h(q[2])
    circuit.ccx(q[0],q[1],q[2])
    circuit.h(q[2])

oracle(qc, qr)
qc.draw(output='mpl')

# %% [markdown]
# Através do statevector a seguir representado podemos verificar que o oráculo está a mudar de fase nos qubits pretendidos.

# %%
backend_state = Aer.get_backend('statevector_simulator')

# %%
result = execute(qc, backend_state).result()
qstate = result.get_statevector(qc)

# %%
qstate
# Out:
# array([ 0.35355339+0.00000000e+00j,  0.35355339+0.00000000e+00j,
#         0.35355339+0.00000000e+00j,  0.35355339-4.32978028e-17j,
#         0.35355339+0.00000000e+00j,  0.35355339+0.00000000e+00j,
#         0.35355339+0.00000000e+00j, -0.35355339+4.32978028e-17j])

# %% [markdown]
# Apresentamos em seguida o statevector em forma de gráficos para melhor visualização.

# %%
plot_state_city(qstate)

# %%
plot_state_hinton(qstate)

# %% [markdown]
# ### Amplificação

# %% [markdown]
# Nesta fase vamos criar um diffuser que nos vai permitir aumentar a amplitude dos qubits de forma a que aumente a probabilidade de obtermos o resultado que pretendemos. Para isso é necessário inverter e aumentar a amplitude da componente pretendidade em torno da média das amplitudes e simultaneamente reduzir das restantes componentes.

# %%
def diffuser(circuit,qr):
    circuit.h(qr)
    circuit.x(qr)
    
    circuit.h(qr[2])
    circuit.ccx(qr[0],qr[1],qr[2])
    circuit.h(qr[2])
    
    circuit.x(qr)
    circuit.h(qr)

# %% [markdown]
# Agora vamos criar um $QuantumCircuit$ que vai conter o nosso oráculo e $diffuser$ aproximadamente $\sqrt{2^n}$ que neste caso vai dar 3.

# %% [markdown]
# Fazemos no fim a medição que consiste na projeção do estado quântico de cada um dos qubits para um bit clássico. Ao ser medido, cada qubit colapsa para um dos estados possíveis, não sendo mais possível obter o estado quântico inicial.

# %%
import math as m

times= round(m.sqrt(2**n))
print(times)
# Out:
# 3

# %%
qc_Grover= QuantumCircuit(qr,cr)

qc_Grover.h(qr)

for t in range(times):
    oracle(qc_Grover,qr)
    
    diffuser(qc_Grover,qr)
    
qc_Grover.measure(qr,cr)

qc_Grover.draw(output='mpl')

# %% [markdown]
# ### Simulação

# %%
backend = Aer.get_backend("qasm_simulator")

# %%
shots=1024
result = execute(qc_Grover, backend, shots=shots).result()
counts_sim = result.get_counts(qc_Grover)
plot_histogram(counts_sim)

# %%
qc_Grover.depth()
# Out:
# 32

# %% [markdown]
# ### Simulação com noise

# %%
provider = IBMQ.load_account()
provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmqx2') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_16_melbourne') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_armonk') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_athens') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_santiago') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_lima') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_quito') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_statevector') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_mps') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_extended_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_manila') from IBMQ(hub='ibm-q', group='open', project='main')>]

# %%
# Backend overview
import qiskit.tools.jupyter

# %qiskit_backend_overview
# Out:
# VBox(children=(HTML(value="<h2 style ='color:#ffffff; background-color:#000000;padding-top: 1%; padding-bottom…

# %%
from qiskit.tools.monitor import backend_overview, backend_monitor

backend_overview()
# Out:
# ibmq_manila                  ibmq_quito                   ibmq_belem
# -----------                  ----------                   ----------
# Num. Qubits:  5              Num. Qubits:  5              Num. Qubits:  5
# Pending Jobs: 12             Pending Jobs: 7              Pending Jobs: 6
# Least busy:   False          Least busy:   False          Least busy:   False
# Operational:  True           Operational:  True           Operational:  True
# Avg. T1:      169.6          Avg. T1:      79.5           Avg. T1:      91.9
# Avg. T2:      60.3           Avg. T2:      72.0           Avg. T2:      88.0
#
#
#
# ibmq_lima                    ibmq_santiago                ibmq_athens
# ---------                    -------------                -----------
# Num. Qubits:  5              Num. Qubits:  5              Num. Qubits:  5
# Pending Jobs: 23             Pending Jobs: 14             Pending Jobs: 7
# Least busy:   False          Least busy:   False          Least busy:   False
# Operational:  True           Operational:  True           Operational:  True
# Avg. T1:      74.7           Avg. T1:      138.9          Avg. T1:      87.6
# Avg. T2:      65.9           Avg. T2:      112.5          Avg. T2:      91.4
#
#
#
# ibmq_armonk                  ibmq_16_melbourne            ibmqx2
# -----------                  -----------------            ------
# Num. Qubits:  1              Num. Qubits:  15             Num. Qubits:  5
# Pending Jobs: 40             Pending Jobs: 327            Pending Jobs: 4
# Least busy:   False          Least busy:   False          Least busy:   True
# Operational:  True           Operational:  True           Operational:  True
# Avg. T1:      227.2          Avg. T1:      53.9           Avg. T1:      55.7
# Avg. T2:      314.7          Avg. T2:      56.2           Avg. T2:      38.0

# %%
backend_device = provider.get_backend('ibmq_belem')
print("Running on: ", backend_device)
# Out:
# Running on:  ibmq_belem

# %%
# See backend information
backend_device
# Out:
# VBox(children=(HTML(value="<h1 style='color:#ffffff;background-color:#000000;padding-top: 1%;padding-bottom: 1…
# <IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q', group='open', project='main')>

# %%
backend_monitor(backend_device)
# Out:
# ibmq_belem
# ==========
# Configuration
# -------------
#     n_qubits: 5
#     operational: True
#     status_msg: active
#     pending_jobs: 5
#     backend_version: 1.0.12
#     basis_gates: ['id', 'rz', 'sx', 'x', 'cx', 'reset']
#     local: False
#     simulator: False
#     quantum_volume: 16
#     meas_map: [[0, 1, 2, 3, 4]]
#     supported_instructions: ['id', 'play', 'u2', 'rz', 'shiftf', 'cx', 'x', 'acquire', 'setf', 'reset', 'measure', 'u3', 'delay', 'u1', 'sx']
#     qubit_lo_range: [[4.590219182601095e+18, 5.590219182601095e+18], [4.745263551401166e+18, 5.745263551401166e+18], [4.860969439099323e+18, 5.860969439099323e+18], [4.670823644105964e+18, 5.670823644105964e+18], [4.758297169246804e+18, 5.758297169246804e+18]]
#     dtm: 0.2222222222222222
#     dt: 0.2222222222222222
#     u_channel_lo: [[{'q': 1, 'scale': (1+0j)}], [{'q': 0, 'scale': (1+0j)}], [{'q': 2, 'scale': (1+0j)}], [{'q': 3, 'scale': (1+0j)}], [{'q': 1, 'scale': (1+0j)}], [{'q': 1, 'scale': (1+0j)}], [{'q': 4, 'scale': (1+0j)}], [{'q': 3, 'scale': (1+0j)}]]
#     processor_type: {'family': 'Falcon', 'revision': 4, 'segment': 'T'}
#     hamiltonian: {'description': 'Qubits are modeled as Duffing oscillators. In this case, the system includes higher energy states, i.e. not just |0> and |1>. The Pauli operators are generalized via the following set of transformations:\n\n$(\\mathbb{I}-\\sigma_{i}^z)/2 \\rightarrow O_i \\equiv b^\\dagger_{i} b_{i}$,\n\n$\\sigma_{+} \\rightarrow b^\\dagger$,\n\n$\\sigma_{-} \\rightarrow b$,\n\n$\\sigma_{i}^X \\rightarrow b^\\dagger_{i} + b_{i}$.\n\nQubits are coupled through resonator buses. The provided Hamiltonian has been projected into the zero excitation subspace of the resonator buses leading to an effective qubit-qubit flip-flop interaction. The qubit resonance frequencies in the Hamiltonian are the cavity dressed frequencies and not exactly what is returned by the backend defaults, which also includes the dressing due to the qubit-qubit interactions.\n\nQuantities are returned in angular frequencies, with units 2*pi*GHz.\n\nWARNING: Currently not all system Hamiltonian information is available to the public, missing values have been replaced with 0.\n', 'h_latex': '\\begin{align} \\mathcal{H}/\\hbar = & \\sum_{i=0}^{4}\\left(\\frac{\\omega_{q,i}}{2}(\\mathbb{I}-\\sigma_i^{z})+\\frac{\\Delta_{i}}{2}(O_i^2-O_i)+\\Omega_{d,i}D_i(t)\\sigma_i^{X}\\right) \\\\ & + J_{0,1}(\\sigma_{0}^{+}\\sigma_{1}^{-}+\\sigma_{0}^{-}\\sigma_{1}^{+}) + J_{1,3}(\\sigma_{1}^{+}\\sigma_{3}^{-}+\\sigma_{1}^{-}\\sigma_{3}^{+}) + J_{3,4}(\\sigma_{3}^{+}\\sigma_{4}^{-}+\\sigma_{3}^{-}\\sigma_{4}^{+}) + J_{1,2}(\\sigma_{1}^{+}\\sigma_{2}^{-}+\\sigma_{1}^{-}\\sigma_{2}^{+}) \\\\ & + \\Omega_{d,0}(U_{0}^{(0,1)}(t))\\sigma_{0}^{X} + \\Omega_{d,1}(U_{1}^{(1,0)}(t)+U_{3}^{(1,3)}(t)+U_{2}^{(1,2)}(t))\\sigma_{1}^{X} \\\\ & + \\Omega_{d,2}(U_{4}^{(2,1)}(t))\\sigma_{2}^{X} + \\Omega_{d,3}(U_{5}^{(3,1)}(t)+U_{6}^{(3,4)}(t))\\sigma_{3}^{X} \\\\ & + \\Omega_{d,4}(U_{7}^{(4,3)}(t))\\sigma_{4}^{X} \\\\ \\end{align}', 'h_str': ['_SUM[i,0,4,wq{i}/2*(I{i}-Z{i})]', '_SUM[i,0,4,delta{i}/2*O{i}*O{i}]', '_SUM[i,0,4,-delta{i}/2*O{i}]', '_SUM[i,0,4,omegad{i}*X{i}||D{i}]', 'jq0q1*Sp0*Sm1', 'jq0q1*Sm0*Sp1', 'jq1q3*Sp1*Sm3', 'jq1q3*Sm1*Sp3', 'jq3q4*Sp3*Sm4', 'jq3q4*Sm3*Sp4', 'jq1q2*Sp1*Sm2', 'jq1q2*Sm1*Sp2', 'omegad1*X0||U0', 'omegad0*X1||U1', 'omegad3*X1||U3', 'omegad2*X1||U2', 'omegad1*X2||U4', 'omegad1*X3||U5', 'omegad4*X3||U6', 'omegad3*X4||U7'], 'osc': {}, 'qub': {'0': 3, '1': 3, '2': 3, '3': 3, '4': 3}, 'vars': {'delta0': -2.1119231275656283, 'delta1': -1.989081364755034, 'delta2': -2.0773937776320905, 'delta3': -2.096945401946966, 'delta4': -2.0819029355928373, 'jq0q1': 0.011772262300160973, 'jq1q2': 0.012605700949390706, 'jq1q3': 0.012591488659137172, 'jq3q4': 0.01051661912410011, 'omegad0': 0.8051992628489011, 'omegad1': 0.778156836600151, 'omegad2': 2.0140766216649526, 'omegad3': 0.7805233989408505, 'omegad4': 0.6465631920808688, 'wq0': 31.98279037844289, 'wq1': 32.95696287844842, 'wq2': 33.68396441198766, 'wq3': 32.4892431466634, 'wq4': 33.03885551459553}}
#     max_experiments: 75
#     acquisition_latency: []
#     n_registers: 1
#     credits_required: True
#     open_pulse: False
#     rep_delay_range: [0.0, 500.0]
#     default_rep_delay: 250.0
#     meas_levels: [1, 2]
#     n_uchannels: 8
#     uchannels_enabled: True
#     online_date: 2021-01-08 05:00:00+00:00
#     backend_name: ibmq_belem
#     url: None
#     meas_lo_range: [[6.801661824e+18, 7.801661824e+18], [6.893428047e+18, 7.893428047e+18], [6.860214726e+18, 7.860214726e+18], [6.803382327e+18, 7.803382327e+18], [6.926310916e+18, 7.926310916e+18]]
#     rep_times: [0.001]
#     max_shots: 8192
#     memory: True
#     discriminators: ['quadratic_discriminator', 'hw_centroid', 'linear_discriminator']
#     conditional: False
#     allow_object_storage: True
#     qubit_channel_mapping: [['u0', 'm0', 'u1', 'd0'], ['u0', 'u2', 'u5', 'm1', 'd1', 'u3', 'u4', 'u1'], ['u4', 'm2', 'd2', 'u2'], ['d3', 'u5', 'u6', 'm3', 'u3', 'u7'], ['m4', 'u6', 'u7', 'd4']]
#     parametric_pulses: ['gaussian', 'gaussian_square', 'drag', 'constant']
#     sample_name: family: Falcon, revision: 4, segment: T
#     coupling_map: [[0, 1], [1, 0], [1, 2], [1, 3], [2, 1], [3, 1], [3, 4], [4, 3]]
#     description: 5 qubit device Belem
#     meas_kernels: ['hw_boxcar']
#     allow_q_object: True
#     dynamic_reprate_enabled: True
#     channels: {'acquire0': {'operates': {'qubits': [0]}, 'purpose': 'acquire', 'type': 'acquire'}, 'acquire1': {'operates': {'qubits': [1]}, 'purpose': 'acquire', 'type': 'acquire'}, 'acquire2': {'operates': {'qubits': [2]}, 'purpose': 'acquire', 'type': 'acquire'}, 'acquire3': {'operates': {'qubits': [3]}, 'purpose': 'acquire', 'type': 'acquire'}, 'acquire4': {'operates': {'qubits': [4]}, 'purpose': 'acquire', 'type': 'acquire'}, 'd0': {'operates': {'qubits': [0]}, 'purpose': 'drive', 'type': 'drive'}, 'd1': {'operates': {'qubits': [1]}, 'purpose': 'drive', 'type': 'drive'}, 'd2': {'operates': {'qubits': [2]}, 'purpose': 'drive', 'type': 'drive'}, 'd3': {'operates': {'qubits': [3]}, 'purpose': 'drive', 'type': 'drive'}, 'd4': {'operates': {'qubits': [4]}, 'purpose': 'drive', 'type': 'drive'}, 'm0': {'operates': {'qubits': [0]}, 'purpose': 'measure', 'type': 'measure'}, 'm1': {'operates': {'qubits': [1]}, 'purpose': 'measure', 'type': 'measure'}, 'm2': {'operates': {'qubits': [2]}, 'purpose': 'measure', 'type': 'measure'}, 'm3': {'operates': {'qubits': [3]}, 'purpose': 'measure', 'type': 'measure'}, 'm4': {'operates': {'qubits': [4]}, 'purpose': 'measure', 'type': 'measure'}, 'u0': {'operates': {'qubits': [0, 1]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u1': {'operates': {'qubits': [1, 0]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u2': {'operates': {'qubits': [1, 2]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u3': {'operates': {'qubits': [1, 3]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u4': {'operates': {'qubits': [2, 1]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u5': {'operates': {'qubits': [3, 1]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u6': {'operates': {'qubits': [3, 4]}, 'purpose': 'cross-resonance', 'type': 'control'}, 'u7': {'operates': {'qubits': [4, 3]}, 'purpose': 'cross-resonance', 'type': 'control'}}
#     conditional_latency: []
#     multi_meas_enabled: True
#
# Qubits [Name / Freq / T1 / T2 / RZ err / SX err / X err / Readout err]
# ----------------------------------------------------------------------
#     Q0 / 5.09022 GHz / 94.09863 us / 109.48919 us / 0.00000 / 0.00020 / 0.00020 / 0.02260
#     Q1 / 5.24526 GHz / 73.01576 us / 76.71550 us / 0.00000 / 0.00027 / 0.00027 / 0.02200
#     Q2 / 5.36097 GHz / 87.86642 us / 45.90972 us / 0.00000 / 0.00034 / 0.00034 / 0.02850
#     Q3 / 5.17082 GHz / 93.31999 us / 80.55628 us / 0.00000 / 0.00033 / 0.00033 / 0.02520
#     Q4 / 5.25830 GHz / 111.36820 us / 127.22920 us / 0.00000 / 0.00026 / 0.00026 / 0.01620
#
# Multi-Qubit Gates [Name / Type / Gate Error]
# --------------------------------------------
#     cx4_3 / cx / 0.00950
#     cx3_4 / cx / 0.00950
#     cx3_1 / cx / 0.00824
#     cx1_3 / cx / 0.00824
#     cx2_1 / cx / 0.01077
#     cx1_2 / cx / 0.01077
#     cx1_0 / cx / 0.01562
#     cx0_1 / cx / 0.01562

# %%
from qiskit.providers.aer.noise import NoiseModel

# %%
coupling_map = backend_device.configuration().coupling_map

# %%
noise_model = NoiseModel.from_backend(backend_device)
print(noise_model)
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'id', 'reset', 'rz', 'sx', 'x']
#   Instructions with noise: ['reset', 'cx', 'measure', 'id', 'sx', 'x']
#   Qubits with noise: [0, 1, 2, 3, 4]
#   Specific qubit errors: [('id', [0]), ('id', [1]), ('id', [2]), ('id', [3]), ('id', [4]), ('sx', [0]), ('sx', [1]), ('sx', [2]), ('sx', [3]), ('sx', [4]), ('x', [0]), ('x', [1]), ('x', [2]), ('x', [3]), ('x', [4]), ('cx', [4, 3]), ('cx', [3, 4]), ('cx', [3, 1]), ('cx', [1, 3]), ('cx', [2, 1]), ('cx', [1, 2]), ('cx', [1, 0]), ('cx', [0, 1]), ('reset', [0]), ('reset', [1]), ('reset', [2]), ('reset', [3]), ('reset', [4]), ('measure', [0]), ('measure', [1]), ('measure', [2]), ('measure', [3]), ('measure', [4])]

# %%
basis_gates = noise_model.basis_gates
print(basis_gates)
# Out:
# ['cx', 'id', 'reset', 'rz', 'sx', 'x']

# %%
result_noise = execute(qc_Grover, backend,
noise_model=noise_model,
coupling_map=coupling_map,
basis_gates=basis_gates).result()
counts_noise = result_noise.get_counts(qc_Grover)
plot_histogram(counts_noise, title="Counts for Groover with depolarizing noise_model")

# %% [markdown]
# ### Simulação num computador quântico

# %%
# %qiskit_job_watcher
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
job_r = execute(qc_Grover, backend_device, shots=shots)

jobID_r = job_r.job_id()

print('JOB ID: {}'.format(jobID_r))
# Out:
# JOB ID: 60b2511d273f30951bb6d1da

# %%
job_get=backend_device.retrieve_job("60b2511d273f30951bb6d1da")

result_r = job_get.result()
counts_run = result_r.get_counts(qc_Grover)

# %%
plot_histogram([counts_run, counts_sim, counts_noise ], legend=[ 'run in real device', 'ideal', "simulation with noise"])

# %% [markdown]
# ### Optimisation

# %% [markdown]
# Decidimos fazer uma optimização de nível 3.

# %%
from qiskit.compiler import transpile
qc_t_real = transpile(qc_Grover, backend=backend_device)
qc_t_real.draw(output='mpl', scale=0.5)

# %%
qc_optimized_3 = transpile(qc_Grover, backend=backend_device,optimization_level=3)
qc_optimized_3.draw(output='mpl', scale=0.5)

# %%
qc_Grover.depth()
# Out:
# 32

# %%
qc_t_real.depth()
# Out:
# 131

# %%
from qiskit.visualization import plot_circuit_layout
plot_circuit_layout(qc_t_real, backend_device)

# %%
qc_optimized_3.depth()
# Out:
# 179

# %%
from qiskit.visualization import plot_circuit_layout
plot_circuit_layout(qc_optimized_3, backend_device)

# %%
job_exp = execute(qc_optimized_3, backend_device, shots = shots)
# job_id allows you to retrive old jobs
jobID = job_exp.job_id()
print('JOB ID: {}'.format(jobID))
job_exp.result().get_counts(qc_optimized_3)
# Out:
# JOB ID: 60b253df8c1d12d1ad5b036b
# {'000': 125,
#  '001': 128,
#  '010': 107,
#  '011': 127,
#  '100': 106,
#  '101': 154,
#  '110': 115,
#  '111': 162}

# %%
job_get_o =backend_device.retrieve_job("60b253df8c1d12d1ad5b036b")
result_opt = job_get_o.result(timeout=3600, wait=5)
counts_opt = result_opt.get_counts(qc_optimized_3)

# %%
plot_histogram(counts_opt)

# %% [markdown]
# ### Ignis

# %% [markdown]
# Vamos agora usar o Ignis para a mitigação de erros.

# %%
from qiskit.ignis.mitigation.measurement import (complete_meas_cal, tensored_meas_cal,
                                                 CompleteMeasFitter, TensoredMeasFitter)

# %% [markdown]
# Começamos por gerar a lista dos circuitos de calibração de medição.
# Como estamos a medir 3 qubits vamos precisar de $2^3=8$ circuitos de calibração.

# %%
qr1 = QuantumRegister(n)
meas_calibs, state_labels = complete_meas_cal(qubit_list=[0,1,2], qr=qr, circlabel='mcal')

# %%
state_labels
# Out:
# ['000', '001', '010', '011', '100', '101', '110', '111']

# %%
job_ignis = execute(meas_calibs, backend=backend_device, shots=shots)
jobID_run_ignis = job_ignis.job_id()
print('JOB ID: {}'.format(jobID_run_ignis))
# Out:
# JOB ID: 60b254a14805f2a4c46d4c82

# %%
job_get=backend_device.retrieve_job("60b254a14805f2a4c46d4c82")
cal_results = job_get.result()

# %%
meas_fitter = CompleteMeasFitter(cal_results, state_labels, circlabel='mcal')
meas_fitter.plot_calibration()

# %%
print("Average Measurement Fidelity: %f" % meas_fitter.readout_fidelity())
# Out:
# Average Measurement Fidelity: 0.920166

# %%
meas_filter = meas_fitter.filter
# Results with mitigation
mitigated_results = meas_filter.apply(result_r)
mitigated_counts = mitigated_results.get_counts()

# %%
plot_histogram([counts_run, mitigated_counts, counts_sim, counts_noise,counts_opt], legend=['raw', 'mitigated', 'ideal',"noise","optimized"])
